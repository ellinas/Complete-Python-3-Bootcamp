# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Milestone Project 2 - Walkthrough Steps Workbook
# Below is a set of steps for you to follow to try to create the Blackjack Milestone Project game!

# %% [markdown]
# ## Game Play
# To play a hand of Blackjack the following steps must be followed:
# 1. Create a deck of 52 cards
# 2. Shuffle the deck
# 3. Ask the Player for their bet
# 4. Make sure that the Player's bet does not exceed their available chips
# 5. Deal two cards to the Dealer and two cards to the Player
# 6. Show only one of the Dealer's cards, the other remains hidden
# 7. Show both of the Player's cards
# 8. Ask the Player if they wish to Hit, and take another card
# 9. If the Player's hand doesn't Bust (go over 21), ask if they'd like to Hit again.
# 10. If a Player Stands, play the Dealer's hand. The dealer will always Hit until the Dealer's value meets or exceeds 17
# 11. Determine the winner and adjust the Player's chips accordingly
# 12. Ask the Player if they'd like to play again

# %% [markdown]
# ## Playing Cards
# A standard deck of playing cards has four suits (Hearts, Diamonds, Spades and Clubs) and thirteen ranks (2 through 10, then the face cards Jack, Queen, King and Ace) for a total of 52 cards per deck. Jacks, Queens and Kings all have a rank of 10. Aces have a rank of either 11 or 1 as needed to reach 21 without busting. As a starting point in your program, you may want to assign variables to store a list of suits, ranks, and then use a dictionary to map ranks to values.

# %% [markdown]
# ## The Game
# ### Imports and Global Variables
# ** Step 1: Import the random module. This will be used to shuffle the deck prior to dealing. Then, declare variables to store suits, ranks and values. You can develop your own system, or copy ours below. Finally, declare a Boolean value to be used to control <code>while</code> loops. This is a common practice used to control the flow of the game.**
#
#     suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
#     ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
#     values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
#              'Queen':10, 'King':10, 'Ace':11}

# %%
import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}

playing = True

# %% [markdown]
# ### Class Definitions
# Consider making a Card class where each Card object has a suit and a rank, then a Deck class to hold all 52 Card objects, and can be shuffled, and finally a Hand class that holds those Cards that have been dealt to each player from the Deck.

# %% [markdown]
# **Step 2: Create a Card Class**<br>
# A Card object really only needs two attributes: suit and rank. You might add an attribute for "value" - we chose to handle value later when developing our Hand class.<br>In addition to the Card's \_\_init\_\_ method, consider adding a \_\_str\_\_ method that, when asked to print a Card, returns a string in the form "Two of Hearts"

# %%
class Card:
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
    
    def __str__(self):
        return self.rank + ' of ' + self.suit

# %% [markdown]
# **Step 3: Create a Deck Class**<br>
# Here we might store 52 card objects in a list that can later be shuffled. First, though, we need to *instantiate* all 52 unique card objects and add them to our list. So long as the Card class definition appears in our code, we can build Card objects inside our Deck \_\_init\_\_ method. Consider iterating over sequences of suits and ranks to build out each card. This might appear inside a Deck class \_\_init\_\_ method:
#
#     for suit in suits:
#         for rank in ranks:
#
# In addition to an \_\_init\_\_ method we'll want to add methods to shuffle our deck, and to deal out cards during gameplay.<br><br>
# OPTIONAL: We may never need to print the contents of the deck during gameplay, but having the ability to see the cards inside it may help troubleshoot any problems that occur during development. With this in mind, consider adding a \_\_str\_\_ method to the class definition.

# %%
class Deck:
    
    def __init__(self):
        self.deck = []  # start with an empty list
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))
    
    def __str__(self):
        readable_deck = ''
        for card in self.deck:
            readable_deck += '\n' + card.__str__()
        return 'The deck has: ' + readable_deck

    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        return self.deck.pop()

# %% [markdown]
# TESTING: Just to see that everything works so far, let's see what our Deck looks like!

# %%
test_deck = Deck()
print(test_deck)
# Out:
# The deck has:
# Two of Hearts
# Three of Hearts
# Four of Hearts
# Five of Hearts
# Six of Hearts
# Seven of Hearts
# Eight of Hearts
# Nine of Hearts
# Ten of Hearts
# Jack of Hearts
# Queen of Hearts
# King of Hearts
# Ace of Hearts
# Two of Diamonds
# Three of Diamonds
# Four of Diamonds
# Five of Diamonds
# Six of Diamonds
# Seven of Diamonds
# Eight of Diamonds
# Nine of Diamonds
# Ten of Diamonds
# Jack of Diamonds
# Queen of Diamonds
# King of Diamonds
# Ace of Diamonds
# Two of Spades
# Three of Spades
# Four of Spades
# Five of Spades
# Six of Spades
# Seven of Spades
# Eight of Spades
# Nine of Spades
# Ten of Spades
# Jack of Spades
# Queen of Spades
# King of Spades
# Ace of Spades
# Two of Clubs
# Three of Clubs
# Four of Clubs
# Five of Clubs
# Six of Clubs
# Seven of Clubs
# Eight of Clubs
# Nine of Clubs
# Ten of Clubs
# Jack of Clubs
# Queen of Clubs
# King of Clubs
# Ace of Clubs

# %% [markdown]
# Great! Now let's move on to our Hand class.

# %% [markdown]
# **Step 4: Create a Hand Class**<br>
# In addition to holding Card objects dealt from the Deck, the Hand class may be used to calculate the value of those cards using the values dictionary defined above. It may also need to adjust for the value of Aces when appropriate.

# %%
class Hand:
    def __init__(self):
        self.cards = []  # start with an empty list as we did in the Deck class
        self.ace_check = []  # start with an empty list as we did in the Deck class
        self.value = 0   # start with zero value
        self.aces = 0    # add an attribute to keep track of aces
    
    def __str__(self):
        readable_hand = ''
        for card in self.cards:
            readable_hand += '\n' + card.__str__()
        return readable_hand
    
    def add_card(self,card):
        self.cards.append(card)
        self.ace_check.append(card)
        self.value += card.value

    def ace_adjust(self):
        while self.value > 21 and len(self.ace_check) > 0:
            if self.ace_check.pop().rank == 'Ace':
                self.value -= 10

# %% [markdown]
# **Step 5: Create a Chips Class**<br>
# In addition to decks of cards and hands, we need to keep track of a Player's starting chips, bets, and ongoing winnings. This could be done using global variables, but in the spirit of object oriented programming, let's make a Chips class instead!

# %%
class Chips:
    
    def __init__(self):
        self.total = 0  # This can be set to a default value or supplied by a user input
        self.bet = 0
        
    def win_bet(self):
        self.total += self.bet
    
    def lose_bet(self):
        self.total -= self.bet

# %% [markdown]
# ### Function Defintions
# A lot of steps are going to be repetitive. That's where functions come in! The following steps are guidelines - add or remove functions as needed in your own program.

# %% [markdown]
# **Step 6: Write a function for taking bets**<br>
# Since we're asking the user for an integer value, this would be a good place to use <code>try</code>/<code>except</code>. Remember to check that a Player's bet can be covered by their available chips.

# %%
def take_bet(chips):
    while True:
        try:
            if 'rolling_total' not in globals():
                chips.total = int(input("Please provide a starting bank: "))
            else:
                chips.total = rolling_total
            chips.bet = int(input("Please provide a bet amount: "))
        except:
            print("Whoops! That is not a number")
            continue
        else:
#             print("Yes thank you")
            if chips.bet > chips.total:
                print("Whoops! bet is greater than total!")
                continue
            else:
                break
#         finally:
#             print("I am going to ask you again!\n")

# %% [markdown]
# **Step 7: Write a function for taking hits**<br>
# Either player can take hits until they bust. This function will be called during gameplay anytime a Player requests a hit, or a Dealer's hand is less than 17. It should take in Deck and Hand objects as arguments, and deal one card off the deck and add it to the Hand. You may want it to check for aces in the event that a player's hand exceeds 21.

# %%
def hit(deck,hand):
    
    hand.add_card(deck.deal())
    hand.ace_adjust()

# %% [markdown]
# **Step 8: Write a function prompting the Player to Hit or Stand**<br>
# This function should accept the deck and the player's hand as arguments, and assign playing as a global variable.<br>
# If the Player Hits, employ the hit() function above. If the Player Stands, set the playing variable to False - this will control the behavior of a <code>while</code> loop later on in our code.

# %%
def hit_or_stand(deck,hand):
    global playing  # to control an upcoming while loop
    while True:
        decision = input("\nHit or Stand? ")
        if decision.lower() == 'hit' or decision.lower() == 'h':
            hit(deck,hand)
        elif decision.lower() == 'stand' or decision.lower() == 's':
            playing = False
        else:
            print("Invalid input! Try again.")
            continue
        break

# %% [markdown]
# **Step 9: Write functions to display cards**<br>
# When the game starts, and after each time Player takes a card, the dealer's first card is hidden and all of Player's cards are visible. At the end of the hand all cards are shown, and you may want to show each hand's total value. Write a function for each of these scenarios.

# %%
def show_some(player,dealer):
    
    print('\nPlayer hand:\n',*player.cards,sep='\n')
    print('\nDealer hand:\n\n' + dealer.cards[1].__str__())
    
def show_all(player,dealer):
    
    print('\nPlayer hand:\n',*player.cards,sep='\n')
    print(f'\nPlayer hand total value: {player.value}')
    print('\nDealer hand:\n',*dealer.cards,sep='\n')
    print(f'\nDealer hand total value: {dealer.value}')

# %% [markdown]
# **Step 10: Write functions to handle end of game scenarios**<br>
# Remember to pass player's hand, dealer's hand and chips as needed.

# %%
def player_busts(chips):
    chips.lose_bet()
    print("\nPlayer has busted")

def player_wins(chips):
    chips.win_bet()
    print("\nPlayer has won")

def dealer_busts(chips):
    chips.win_bet()
    print("\nDealer has busted")
    
def dealer_wins(chips):
    chips.lose_bet()
    print("\nDealer has won")
    
def push():
    print("\nTied round")

# %% [markdown]
# ### And now on to the game!!

# %%
while True:
    # Print an opening statement
    print("Welcome to blackjack!\n")
    playing = True

    # Create & shuffle the deck, deal two cards to each player
    new_deck = Deck()
    new_deck.shuffle()
    
    player_hand = Hand()
    hit(new_deck,player_hand)
    hit(new_deck,player_hand)
    
    dealer_hand = Hand()
    hit(new_deck,dealer_hand)
    hit(new_deck,dealer_hand)

    # Set up the Player's chips
    player_chips = Chips()
    
    # Prompt the Player for their bet
    take_bet(player_chips)
    
    # Show cards (but keep one dealer card hidden)
    show_some(player_hand,dealer_hand)
    
    while playing:  # recall this variable from our hit_or_stand function
        
        # Prompt for Player to Hit or Stand
        hit_or_stand(new_deck,player_hand)
        
        # Show cards (but keep one dealer card hidden)
        show_some(player_hand,dealer_hand)
        
        # If player's hand exceeds 21, run player_busts() and break out of loop
        if player_hand.value > 21:
            player_busts(player_chips)
            break

    # If Player hasn't busted, play Dealer's hand until Dealer reaches 17
    if player_hand.value <= 21:
        # Show all cards
        show_all(player_hand,dealer_hand)
        while dealer_hand.value < 17:
            hit(new_deck,dealer_hand)
            show_all(player_hand,dealer_hand)
    
        # Run different winning scenarios
        if dealer_hand.value > 21:
            dealer_busts(player_chips)
        elif player_hand.value > dealer_hand.value:
            player_wins(player_chips)
        elif dealer_hand.value > player_hand.value:
            dealer_wins(player_chips)
        else:
            push()
        
# Inform Player of their chips total 
    print(f'\nCurrent chip total: {player_chips.total}')
    rolling_total = player_chips.total
    if player_chips.total <= 0:
        del rolling_total
        print("Out of chips!")
        break
    else:
# Ask to play again
        go_again = input("\nPlay again? ")
        if go_again.lower() == 'yes' or go_again.lower() == 'y':
            continue
        else:
            print('\nThanks for playing!')
            del rolling_total
            break
# Out:
# Welcome to blackjack!
#
# Please provide a starting bank: 100
# Please provide a bet amount: 10
#
# Player hand:
#
# Queen of Diamonds
# Six of Diamonds
#
# Dealer hand:
#
# Ace of Diamonds
#
# Hit or Stand? h
#
# Player hand:
#
# Queen of Diamonds
# Six of Diamonds
# Jack of Clubs
#
# Dealer hand:
#
# Ace of Diamonds
#
# Player has busted
#
# Current chip total: 90
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 20
#
# Player hand:
#
# Two of Hearts
# Two of Clubs
#
# Dealer hand:
#
# Seven of Spades
#
# Hit or Stand? h
#
# Player hand:
#
# Two of Hearts
# Two of Clubs
# King of Hearts
#
# Dealer hand:
#
# Seven of Spades
#
# Hit or Stand? h
#
# Player hand:
#
# Two of Hearts
# Two of Clubs
# King of Hearts
# Ace of Diamonds
#
# Dealer hand:
#
# Seven of Spades
#
# Hit or Stand? h
#
# Player hand:
#
# Two of Hearts
# Two of Clubs
# King of Hearts
# Ace of Diamonds
# Four of Diamonds
#
# Dealer hand:
#
# Seven of Spades
#
# Hit or Stand? s
#
# Player hand:
#
# Two of Hearts
# Two of Clubs
# King of Hearts
# Ace of Diamonds
# Four of Diamonds
#
# Dealer hand:
#
# Seven of Spades
#
# Player hand:
#
# Two of Hearts
# Two of Clubs
# King of Hearts
# Ace of Diamonds
# Four of Diamonds
#
# Player hand total value: 19
#
# Dealer hand:
#
# Nine of Diamonds
# Seven of Spades
#
# Dealer hand total value: 16
#
# Player hand:
#
# Two of Hearts
# Two of Clubs
# King of Hearts
# Ace of Diamonds
# Four of Diamonds
#
# Player hand total value: 19
#
# Dealer hand:
#
# Nine of Diamonds
# Seven of Spades
# Five of Hearts
#
# Dealer hand total value: 21
#
# Dealer has won
#
# Current chip total: 70
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 30
#
# Player hand:
#
# Two of Hearts
# Jack of Diamonds
#
# Dealer hand:
#
# Two of Clubs
#
# Hit or Stand? h
#
# Player hand:
#
# Two of Hearts
# Jack of Diamonds
# Seven of Spades
#
# Dealer hand:
#
# Two of Clubs
#
# Hit or Stand? s
#
# Player hand:
#
# Two of Hearts
# Jack of Diamonds
# Seven of Spades
#
# Dealer hand:
#
# Two of Clubs
#
# Player hand:
#
# Two of Hearts
# Jack of Diamonds
# Seven of Spades
#
# Player hand total value: 19
#
# Dealer hand:
#
# Ace of Clubs
# Two of Clubs
#
# Dealer hand total value: 13
#
# Player hand:
#
# Two of Hearts
# Jack of Diamonds
# Seven of Spades
#
# Player hand total value: 19
#
# Dealer hand:
#
# Ace of Clubs
# Two of Clubs
# King of Spades
#
# Dealer hand total value: 13
#
# Player hand:
#
# Two of Hearts
# Jack of Diamonds
# Seven of Spades
#
# Player hand total value: 19
#
# Dealer hand:
#
# Ace of Clubs
# Two of Clubs
# King of Spades
# Four of Clubs
#
# Dealer hand total value: 17
#
# Player has won
#
# Current chip total: 100
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 20
#
# Player hand:
#
# Jack of Diamonds
# Six of Clubs
#
# Dealer hand:
#
# Five of Hearts
#
# Hit or Stand? h
#
# Player hand:
#
# Jack of Diamonds
# Six of Clubs
# Two of Clubs
#
# Dealer hand:
#
# Five of Hearts
#
# Hit or Stand? s
#
# Player hand:
#
# Jack of Diamonds
# Six of Clubs
# Two of Clubs
#
# Dealer hand:
#
# Five of Hearts
#
# Player hand:
#
# Jack of Diamonds
# Six of Clubs
# Two of Clubs
#
# Player hand total value: 18
#
# Dealer hand:
#
# Queen of Hearts
# Five of Hearts
#
# Dealer hand total value: 15
#
# Player hand:
#
# Jack of Diamonds
# Six of Clubs
# Two of Clubs
#
# Player hand total value: 18
#
# Dealer hand:
#
# Queen of Hearts
# Five of Hearts
# Three of Diamonds
#
# Dealer hand total value: 18
#
# Tied round
#
# Current chip total: 100
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 20
#
# Player hand:
#
# Jack of Hearts
# King of Spades
#
# Dealer hand:
#
# Seven of Spades
#
# Hit or Stand? s
#
# Player hand:
#
# Jack of Hearts
# King of Spades
#
# Dealer hand:
#
# Seven of Spades
#
# Player hand:
#
# Jack of Hearts
# King of Spades
#
# Player hand total value: 20
#
# Dealer hand:
#
# Ten of Diamonds
# Seven of Spades
#
# Dealer hand total value: 17
#
# Player has won
#
# Current chip total: 120
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 30
#
# Player hand:
#
# Queen of Clubs
# Jack of Diamonds
#
# Dealer hand:
#
# Six of Spades
#
# Hit or Stand? s
#
# Player hand:
#
# Queen of Clubs
# Jack of Diamonds
#
# Dealer hand:
#
# Six of Spades
#
# Player hand:
#
# Queen of Clubs
# Jack of Diamonds
#
# Player hand total value: 20
#
# Dealer hand:
#
# Eight of Diamonds
# Six of Spades
#
# Dealer hand total value: 14
#
# Player hand:
#
# Queen of Clubs
# Jack of Diamonds
#
# Player hand total value: 20
#
# Dealer hand:
#
# Eight of Diamonds
# Six of Spades
# Seven of Diamonds
#
# Dealer hand total value: 21
#
# Dealer has won
#
# Current chip total: 90
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 30
#
# Player hand:
#
# King of Clubs
# Two of Clubs
#
# Dealer hand:
#
# Seven of Spades
#
# Hit or Stand? h
#
# Player hand:
#
# King of Clubs
# Two of Clubs
# Four of Hearts
#
# Dealer hand:
#
# Seven of Spades
#
# Hit or Stand? h
#
# Player hand:
#
# King of Clubs
# Two of Clubs
# Four of Hearts
# Five of Spades
#
# Dealer hand:
#
# Seven of Spades
#
# Hit or Stand? s
#
# Player hand:
#
# King of Clubs
# Two of Clubs
# Four of Hearts
# Five of Spades
#
# Dealer hand:
#
# Seven of Spades
#
# Player hand:
#
# King of Clubs
# Two of Clubs
# Four of Hearts
# Five of Spades
#
# Player hand total value: 21
#
# Dealer hand:
#
# Nine of Clubs
# Seven of Spades
#
# Dealer hand total value: 16
#
# Player hand:
#
# King of Clubs
# Two of Clubs
# Four of Hearts
# Five of Spades
#
# Player hand total value: 21
#
# Dealer hand:
#
# Nine of Clubs
# Seven of Spades
# Ace of Diamonds
#
# Dealer hand total value: 17
#
# Player has won
#
# Current chip total: 120
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 30
#
# Player hand:
#
# Seven of Spades
# Seven of Clubs
#
# Dealer hand:
#
# Two of Spades
#
# Hit or Stand? h
#
# Player hand:
#
# Seven of Spades
# Seven of Clubs
# Two of Diamonds
#
# Dealer hand:
#
# Two of Spades
#
# Hit or Stand? h
#
# Player hand:
#
# Seven of Spades
# Seven of Clubs
# Two of Diamonds
# Nine of Spades
#
# Dealer hand:
#
# Two of Spades
#
# Player has busted
#
# Current chip total: 90
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 50
#
# Player hand:
#
# Two of Hearts
# Three of Hearts
#
# Dealer hand:
#
# Five of Spades
#
# Hit or Stand? h
#
# Player hand:
#
# Two of Hearts
# Three of Hearts
# Queen of Hearts
#
# Dealer hand:
#
# Five of Spades
#
# Hit or Stand? h
#
# Player hand:
#
# Two of Hearts
# Three of Hearts
# Queen of Hearts
# Two of Clubs
#
# Dealer hand:
#
# Five of Spades
#
# Hit or Stand? s
#
# Player hand:
#
# Two of Hearts
# Three of Hearts
# Queen of Hearts
# Two of Clubs
#
# Dealer hand:
#
# Five of Spades
#
# Player hand:
#
# Two of Hearts
# Three of Hearts
# Queen of Hearts
# Two of Clubs
#
# Player hand total value: 17
#
# Dealer hand:
#
# Four of Spades
# Five of Spades
#
# Dealer hand total value: 9
#
# Player hand:
#
# Two of Hearts
# Three of Hearts
# Queen of Hearts
# Two of Clubs
#
# Player hand total value: 17
#
# Dealer hand:
#
# Four of Spades
# Five of Spades
# King of Diamonds
#
# Dealer hand total value: 19
#
# Dealer has won
#
# Current chip total: 40
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 40
#
# Player hand:
#
# Seven of Diamonds
# Nine of Hearts
#
# Dealer hand:
#
# Nine of Spades
#
# Hit or Stand? h
#
# Player hand:
#
# Seven of Diamonds
# Nine of Hearts
# Five of Clubs
#
# Dealer hand:
#
# Nine of Spades
#
# Hit or Stand? s
#
# Player hand:
#
# Seven of Diamonds
# Nine of Hearts
# Five of Clubs
#
# Dealer hand:
#
# Nine of Spades
#
# Player hand:
#
# Seven of Diamonds
# Nine of Hearts
# Five of Clubs
#
# Player hand total value: 21
#
# Dealer hand:
#
# King of Spades
# Nine of Spades
#
# Dealer hand total value: 19
#
# Player has won
#
# Current chip total: 80
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 40
#
# Player hand:
#
# Two of Clubs
# Three of Hearts
#
# Dealer hand:
#
# Seven of Spades
#
# Hit or Stand? h
#
# Player hand:
#
# Two of Clubs
# Three of Hearts
# Nine of Diamonds
#
# Dealer hand:
#
# Seven of Spades
#
# Hit or Stand? h
#
# Player hand:
#
# Two of Clubs
# Three of Hearts
# Nine of Diamonds
# Seven of Hearts
#
# Dealer hand:
#
# Seven of Spades
#
# Hit or Stand? s
#
# Player hand:
#
# Two of Clubs
# Three of Hearts
# Nine of Diamonds
# Seven of Hearts
#
# Dealer hand:
#
# Seven of Spades
#
# Player hand:
#
# Two of Clubs
# Three of Hearts
# Nine of Diamonds
# Seven of Hearts
#
# Player hand total value: 21
#
# Dealer hand:
#
# Four of Hearts
# Seven of Spades
#
# Dealer hand total value: 11
#
# Player hand:
#
# Two of Clubs
# Three of Hearts
# Nine of Diamonds
# Seven of Hearts
#
# Player hand total value: 21
#
# Dealer hand:
#
# Four of Hearts
# Seven of Spades
# Two of Spades
#
# Dealer hand total value: 13
#
# Player hand:
#
# Two of Clubs
# Three of Hearts
# Nine of Diamonds
# Seven of Hearts
#
# Player hand total value: 21
#
# Dealer hand:
#
# Four of Hearts
# Seven of Spades
# Two of Spades
# Jack of Diamonds
#
# Dealer hand total value: 23
#
# Dealer has busted
#
# Current chip total: 120
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 30
#
# Player hand:
#
# King of Spades
# Ace of Diamonds
#
# Dealer hand:
#
# Nine of Clubs
#
# Hit or Stand? s
# Player hand:
#
# King of Spades
# Ace of Diamonds
#
# Dealer hand:
#
# Nine of Clubs
#
# Player hand:
#
# King of Spades
# Ace of Diamonds
#
# Player hand total value: 21
#
# Dealer hand:
#
# Five of Hearts
# Nine of Clubs
#
# Dealer hand total value: 14
#
# Player hand:
#
# King of Spades
# Ace of Diamonds
#
# Player hand total value: 21
#
# Dealer hand:
#
# Five of Hearts
# Nine of Clubs
# Four of Hearts
#
# Dealer hand total value: 18
#
# Player has won
#
# Current chip total: 150
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 30
#
# Player hand:
#
# Four of Hearts
# Ace of Spades
#
# Dealer hand:
#
# Two of Diamonds
#
# Hit or Stand? h
#
# Player hand:
#
# Four of Hearts
# Ace of Spades
# Two of Spades
#
# Dealer hand:
#
# Two of Diamonds
#
# Hit or Stand? s
#
# Player hand:
#
# Four of Hearts
# Ace of Spades
# Two of Spades
#
# Dealer hand:
#
# Two of Diamonds
#
# Player hand:
#
# Four of Hearts
# Ace of Spades
# Two of Spades
#
# Player hand total value: 17
#
# Dealer hand:
#
# Ace of Clubs
# Two of Diamonds
#
# Dealer hand total value: 13
#
# Player hand:
#
# Four of Hearts
# Ace of Spades
# Two of Spades
#
# Player hand total value: 17
#
# Dealer hand:
#
# Ace of Clubs
# Two of Diamonds
# Seven of Diamonds
#
# Dealer hand total value: 20
#
# Dealer has won
#
# Current chip total: 120
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 30
#
# Player hand:
#
# King of Clubs
# Seven of Hearts
#
# Dealer hand:
#
# Four of Clubs
#
# Hit or Stand? s
#
# Player hand:
#
# King of Clubs
# Seven of Hearts
#
# Dealer hand:
#
# Four of Clubs
#
# Player hand:
#
# King of Clubs
# Seven of Hearts
#
# Player hand total value: 17
#
# Dealer hand:
#
# Seven of Diamonds
# Four of Clubs
#
# Dealer hand total value: 11
#
# Player hand:
#
# King of Clubs
# Seven of Hearts
#
# Player hand total value: 17
#
# Dealer hand:
#
# Seven of Diamonds
# Four of Clubs
# Jack of Hearts
#
# Dealer hand total value: 21
#
# Dealer has won
#
# Current chip total: 90
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 50
#
# Player hand:
#
# King of Diamonds
# Jack of Spades
#
# Dealer hand:
#
# Nine of Clubs
#
# Hit or Stand? s
#
# Player hand:
#
# King of Diamonds
# Jack of Spades
#
# Dealer hand:
#
# Nine of Clubs
#
# Player hand:
#
# King of Diamonds
# Jack of Spades
#
# Player hand total value: 20
#
# Dealer hand:
#
# Four of Diamonds
# Nine of Clubs
#
# Dealer hand total value: 13
#
# Player hand:
#
# King of Diamonds
# Jack of Spades
#
# Player hand total value: 20
#
# Dealer hand:
#
# Four of Diamonds
# Nine of Clubs
# Two of Hearts
#
# Dealer hand total value: 15
#
# Player hand:
#
# King of Diamonds
# Jack of Spades
#
# Player hand total value: 20
#
# Dealer hand:
#
# Four of Diamonds
# Nine of Clubs
# Two of Hearts
# Ace of Spades
#
# Dealer hand total value: 16
#
# Player hand:
#
# King of Diamonds
# Jack of Spades
#
# Player hand total value: 20
#
# Dealer hand:
#
# Four of Diamonds
# Nine of Clubs
# Two of Hearts
# Ace of Spades
# Seven of Hearts
#
# Dealer hand total value: 23
#
# Dealer has busted
#
# Current chip total: 140
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 30
#
# Player hand:
#
# King of Diamonds
# Queen of Diamonds
#
# Dealer hand:
#
# Ten of Spades
#
# Hit or Stand? s
#
# Player hand:
#
# King of Diamonds
# Queen of Diamonds
#
# Dealer hand:
#
# Ten of Spades
#
# Player hand:
#
# King of Diamonds
# Queen of Diamonds
#
# Player hand total value: 20
#
# Dealer hand:
#
# Six of Hearts
# Ten of Spades
#
# Dealer hand total value: 16
#
# Player hand:
#
# King of Diamonds
# Queen of Diamonds
#
# Player hand total value: 20
#
# Dealer hand:
#
# Six of Hearts
# Ten of Spades
# Eight of Spades
#
# Dealer hand total value: 24
#
# Dealer has busted
#
# Current chip total: 170
#
# Play again? y
# Welcome to blackjack!
#
# Please provide a bet amount: 30
#
# Player hand:
#
# Queen of Clubs
# Jack of Diamonds
#
# Dealer hand:
#
# Ten of Hearts
#
# Hit or Stand? s
#
# Player hand:
#
# Queen of Clubs
# Jack of Diamonds
#
# Dealer hand:
#
# Ten of Hearts
#
# Player hand:
#
# Queen of Clubs
# Jack of Diamonds
#
# Player hand total value: 20
#
# Dealer hand:
#
# Three of Clubs
# Ten of Hearts
#
# Dealer hand total value: 13
#
# Player hand:
#
# Queen of Clubs
# Jack of Diamonds
#
# Player hand total value: 20
#
# Dealer hand:
#
# Three of Clubs
# Ten of Hearts
# Five of Spades
#
# Dealer hand total value: 18
#
# Player has won
#
# Current chip total: 200
#
# Play again? n
#
# Thanks for playing!

# %% [markdown]
# # And that's it! Remember, these steps may differ significantly from your own solution. That's OK! Keep working on different sections of your program until you get the desired results. It takes a lot of time and patience! As always, feel free to post questions and comments to the QA Forums.
# # Good job!
